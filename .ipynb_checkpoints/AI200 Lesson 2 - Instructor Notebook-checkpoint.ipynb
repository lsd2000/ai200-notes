# %% [markdown]
# <img src="data:image/png;base64,...
# " style="width:125px;height:85px">

# %% [markdown]
# ***
# # HEICODERS ACADEMY
# <b>AI200: Applied Machine Learning</b><br>
# ***
# <b>Lesson 2:</b> Advanced Data Visualisations with Plotly.Express [Instructor Notebook]
# ***
#
# <b>Learning outcomes:</b>
#
# - Understand and appreciate the purposes and use cases of data visualisation
# - Master the workflow of implementing and customising interactive data visualisations with plotly.express
# - Gain an intuition for selecting the appropriate data visualisation (relationship, composition, comparison & distribution) for different types of data
# - Learn the use cases and implementations of the following visualisation techniques:
#     - Scatterplot
#     - Scatterplot matrix
#     - Heatmap
#     - Bubble Chart
#     - Animated Bubble Chart
#     - Stacked Column Chart
#     - Stacked Area Chart
#     - Pie Chart
#     - Treemap
#     - Histogram
#     - Boxplot
#     - Line Chart
#     - Bar Chart
# - Understand how data visualisations can be deployed to a server accessible by URL, using Dash
#
# <b>Last Updated: 26 May 2024</b>

# %% [markdown]
# <b>Datasets Used:</b>
#
# - Stock prices from Yahoo Finance API - using `yfinance` library
# - Credit Card Spending Analysis
# - Gapminder Countries Ecnonomics Development Statistics Dataset from [plotly](https://plotly.com/python-api-reference/generated/plotly.data.html#plotly.data.gapminder)
# - Singapore Domestic Loans by Market Share in 2017
# - Top US Banks in terms of Market Capitalisation

# %% [markdown]
# <b>Content</b>
#
# - [1.The Big Picture](#1.The-Big-Picture)
#     - [1a. Scope of Lesson 2 Visualisation](#1a.-Scope-of-Lesson-2-Visualisation)
#     - [1b. What is Data Visualisation?](#1b.-What-is-Data-Visualisation?)
#     - [1c. Case Study: Circle Line Rogue Train Incident (Optional)](#1c.-Case-Study:-Circle-Line-Rogue-Train-Incident-(Optional))
# - [2.Introduction to Plotly](#2.Introduction-to-Plotly)
#     - [2a. What is Plotly, and Why Plotly?](#2a.-What-is-Plotly,-and-Why-Plotly?)
#     - [2b. Understanding Plotly's Ecosystem & Resources](#2b.-Understanding-Plotly's-Ecosystem-&-Resources)
# - [3.Workflow for Generating Plotly.express Visualisations](#3.Workflow-for-Generating-Plotly.express-Visualisations)
#     - [3a. Structure of this Section](#3a.-Structure-of-this-Section)
#     - [3b. Install and Import Plotly.express](#3b.-Install-and-Import-Plotly.express)
#     - [3c. Navigating Plotly.express documentations and Initiating with Sample Codes](#3c.-Navigating-Plotly.express-documentations-and-Initiating-with-Sample-Codes)
#     - [3d. Customising your Visualisations with Plotly.express](#3d.-Customising-your-Visualisations-with-Plotly.express)
#     - [3e. Generate a Plotly.express Visualisation [Student Exercise]](#3e.-Generate-a-Plotly.express-Visualisation-[Student-Exercise])
#     - [3f. Formalising how Data Transformation Phase Segues into Plotly.express Visualisations](#3f.-Formalising-how-Data-Transformation-Phase-Segues-into-Plotly.express-Visualisations)
# - [4.Use Cases for Select Visualisations](#4.Use-Cases-for-Select-Visualisations)
#     - [4a. Recommended Principles for Selecting Visualisations](#4a.-Recommended-Principles-for-Selecting-Visualisations)
#     - [4b. Exposure to Select Visualisations and their Use Cases](#4b.-Exposure-to-Select-Visualisations-and-their-Use-Cases)
#     - [4c. Visualisations for Relationship](#4c.-Visualisations-for-Relationship)
#     - [4d. Visualisations for Composition (Overtime)](#4d.-Visualisations-for-Composition-(Overtime))
#     - [4e. Visualisations for Composition (Static)](#4e.-Visualisations-for-Composition-(Static))
#     - [4f. Visualisations for Distribution](#4f.-Visualisations-for-Distribution)
#     - [4g. Visualisations for Comparison](#4g.-Visualisations-for-Comparison)
#     - [4h. Visualisations for Comparison - Bar Chart [Student Exercise]](#4h.-Visualisations-for-Comparison---Bar-Chart-[Student-Exercise])
# - [5.Useful Resources / Advice](#5.Useful-Resources-/-Advice)
#     - [5a. Plotly Datasets](#5a.-Plotly-Datasets)
#     - [5b. Deploying your Visualisation with Dash](#5b.-Deploying-your-Visualisation-with-Dash)
#     - [5c. Common Fallacies in Data Visualisations](#5c.-Common-Fallacies-in-Data-Visualisations)

# %% [markdown]
# 1.The Big Picture
# ===
# ***

# %% [markdown]
# 1a. Scope of Lesson 2 Visualisation
# ---

# %% [markdown]
# <img src='data:image/png;base64,...
# ' width='800'/>

# %% [markdown]
# As mentioned in the previous session, typically the Exploratory Data Analysis (EDA) step comprises of two components:
#
# - Generate descriptive summary data (e.g. using pandas <code>describe()</code>)
# - Generate graphical visualisations
#
# In the previous session, we covered how to <b>generate descriptive summary data </b>, and also how to <b>manipulate and transform the data for visualisation libraries</b> using a host of Pandas operations & functions. In this session, we are going to show you how to integrate your pandas data manipulation work into graphical visualisations. Broadly, the scope is as such:<br>
#
# - Generate graphical visualisations with data transformed via Pandas
# - Implement and make sense of new graphical visualisations which were not taught in AI100 (e.g. matrix plot, correlation plot)
# - Understand how to use Plotly can be used to implement basic and advanced interactive visualisations
# - Internalise the thought process / framework for choosing the right type of visualisation for the data  (The examples in this notebook are based on a variety of datasets to help you)

# %% [markdown]
# 1b. What is Data Visualisation?
# ---
#
# Data visualization is the<b> graphical representation of information and data</b>. Visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data.
#
# In the world of Big Data, data visualization tools and technologies are essential to analyze massive amounts of information and make data-driven decisions.
#
# Our eyes are drawn to colors and patterns. We can quickly identify red from blue, square from circle. Our culture is visual, including everything from art and advertisements to TV and movies. When we see a chart, we quickly see trends and outliers. If we can see something, we internalize it quickly. It’s storytelling with a purpose. If you’ve ever stared at a massive spreadsheet of data and couldn’t see a trend, you know how much more effective a visualization can be.
#
# There are two ways to generate data visualisations:
# - Use software which you don't have to do any coding (tableau, Qlik)
# - Code your own visualisation using graphical libraries (Matplotlib, Seaborn, Bokeh, Plotly, Folium)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Before we begin, we just want to leave you with one word of advice: Don't view visualisation as just a supplementary tool to help you understand the data or improve your machine learning model. A well-formed visualisation can be the very solution to your problem, and drive positive business impact (Read case study on your own below).
# </div>

# %% [markdown]
# 1c. Case Study: Circle Line Rogue Train Incident (Optional)
# ---
#
# <img src='data:image/png;base64,...
# ' width='600'/>

# %% [markdown]
# Read more about how data analysts at GovTech used visualisation to solve the rogue train problem:<br>
# https://medium.com/datagovsg-blog/how-we-caught-the-circle-line-rogue-train-with-data-79405c86ab6a

# %% [markdown]
# 2.Introduction to Plotly
# ===
# ***

# %% [markdown]
# 2a. What is Plotly, and Why Plotly?
# ---
#
# Previously in AI100, we covered how to implement various graphical visualisation using Matplotlib and Folium. Today, we focus on <b>Plotly</b>, one of the most popular and powerful <b>interactive visualisation</b> libraries today. You can find the documentations & more sample code at: https://plotly.com/python/

# %% [markdown]
# Before we begin, here is why we chose to focus on plotly in this course, instead of say Seaborn which is also popular:
#
# - Plotly is best in class in terms of aesthetics
# - Can directly deploy your graph / dashboard as a web application (via Dash)
# - This library is available to R, Julia or Python. So if you ever need to work on a project or join a team that uses any of these languages other than Python, you don't have to relearn the basics unlike another visualisation library
# - Plotly is super efficient, and you will be able to generate powerful and aesthetically appealing graphs, that are also interactive (this is a feature privvy to only a few select libraries) with very few lines of code <b>as shown in the image below</b>

# %% [markdown]
# <img src='data:image/png;base64,...
# ' width='800'/>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# In essence, Plotly is one of the most cutting-edge visualisation library, aka the coolest-kid-on-the-block where visualisation is concerned.
# </div>

# %% [markdown]
# 2b. Understanding Plotly's Ecosystem & Resources
# ---
#
# While Plotly is very cutting-edge and offers a vast array of tools, it can be very overwhelming especially to an unexperienced programmer or someone who is new to Plotly. But once you understand where to look for the relevant resources, you will find Plotly extremely easy to navigate. Especially for those that took AI100, you will see how much easier it is to create visualisation vis-a-vis with Matplotlib. <br>
#
# Let's start by debunking some of the common confusion about the resources in plotly. <b>Once you know where to look for the relevant resources in Plotly, half the battle is already won</b>. When you first navigate plotly's documentations, you would often see references to these 3 resources:

# %% [markdown]
# <img src='data:image/png;base64,...
# ' width='600'/>

# %% [markdown]
# The focus of this lessons will be on mastery of <code>plotly.express</code> since this will be the very sub-module we will be using the majority of the time as Data Scientist / Data Analyst.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Here is an analogy to help you remember:
#
# - <code>plotly.graph_objects</code> is like a manual car, where you have more control over the car.
# - <code>plotly.express</code> is like an automatic car, where you have less control, but you don't have to worry about shifting gears and can just focus on steering the car, making driving easier.</div>

# %% [markdown]
# 3.Workflow for Generating Plotly.express Visualisations
# ===
# ***

# %% [markdown]
# 3a. Structure of this Section
# ---

# %% [markdown]
# In this section, we will <b>use scatter plot as an example to walk you through the workflow (3b to 3d) for generating visualisation with plotly</b>. Through this workflow, you will begin to form a subtle idea of how the pandas dataframe we learnt to transform/manipulate are integrated with data visualisation. We will <b>formalise and reinforce this subtle idea  at the end of this section</b>.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# It is highly important that you have a formalised workflow, especially when dealing with a complex and sophisicated library like Plotly. This will greatly cut down your implementation time. In fact, you can/should use this workflow when working with other libraries beyond Plotly!
# </div>

# %% [markdown]
# 3b. Install and Import Plotly.express
# ---
# To use Plotly, you'll need to first install <code>plotly</code>

# %%
# Run this cell to install plotly (you only need to do this once)
# !pip install plotly==5.19.0

# %% [markdown]
# Thereafter, we need to <code>import plotly.express as px</code>. While it isn't necessary , the use of the <code>px</code> alias is an industry convention when it comes to Plotly.express. And since it makes calling plotly  way easier with less typing required, we will follow this convention as well.

# %%
import plotly.express as px

# %% [markdown]
# 3c. Navigating Plotly.express documentations and Initiating with Sample Codes
# ---

# %% [markdown]
# Here, we would do the following:
#
# i) Navigate the plotly.express documentations and initiate with sample codes <br>
# ii) Edit sample code to visualise your dataframes

# %% [markdown]
# <b>3c.i) Navigate the plotly.express documentations and initiate with sample codes</b>
#
# In this step, we will navigate the plotly.express documentations to look for the sample code of the type of visualisation (e.g. line chart) which we are trying to generate. Typically, we would start navigating from the 3 links below to look for relevant sample codes (there are other pages in the website that has sample codes as well): <br>
# - https://plotly.com/python/
# - https://plotly.com/python/plotly-express/#overview
# - https://plotly.com/python-api-reference/plotly.express.html (for users who are already well acquainted with plotly)

# %% [markdown]
# Now let's bring together everything in a concrete workflow. For example if we wanted to create a scattered plot with our data, our workflow would be as such:
#
# - Go to https://plotly.com/python/
# - Click on the <b>Basic Charts</b> tab on the navigation pane, and you will be redirected to: https://plotly.com/python/basic-charts/
# - Click on the <b>Scatter Plots</b> option, and you will be redirected to: https://plotly.com/python/line-and-scatter/
# - You will see a sample code for scatter plot (see below), and you should copy the code customise for your own data:<br>

# %% [markdown]
# <img src='data:image/png;base64,...
# ' width='600'/>

# %%
# Below is our sample code for scatter plot, taken from the above image
import plotly.express as px

df = px.data.iris() # iris is a pandas DataFrame
fig = px.scatter(df, x="sepal_width", y="sepal_length")
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# The idea is, once you see the line <code>import plotly.express as px</code> within the sample code, you know that it is implemented using the <code>plotly.express</code>, and as such is the sample code you are looking for. As a side note, remember we mentioned that <b>Plotly</b> is an <b>interactive</b> visualistion library? Try playing with the graph above to see what is so special about <b>Plotly</b> visualisations.
# </div>

# %% [markdown]
# <code>df</code> is just a regular dataframe. Notice that we are just passing in <b>(1) a dataframe, (2) a column name from the dataframe to be the x-axis of the graph, and (3)  a column name from the dataframe to be the y-axis of the graph</b>. Let's just print the contents of the dataframe to inspect the content so that it will give you more clarity.

# %%
df.head()

# %% [markdown]
# <b>3c.ii) Edit sample code to visualise your dataframes</b>
#
# Using the sample code, it is very easy to understand the breakdown (see image below) of the Plotly functions (<code>scatter()</code> in this case).
#
# <img src='data:image/png;base64,...
# ' width='600'/>

# %% [markdown]
# All we need to do then is to <b>replace the sample data in the sample code with our own data</b>. For example, if we want to visualise the dataset below (on credit card spending dataset)

# %%
import pandas as pd

creditcard_spending_df = pd.read_csv("data/credit_card_spending.csv")
creditcard_spending_df.head()

# %% [markdown]
# Notice that all we needed to do it just tweak the parameters we pass into the <code>scatter()</code> function, and our job is done!

# %%
fig = px.scatter(creditcard_spending_df,
                 x='total_credit_card_bill',
                 y='amount_spent_on_alcohol'
)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Imagine you work in a credit card company, and you wish to know which customer segment and on which day to push out promotion to advocate more consumer spending on alchol! Using EDA, you can uncover some patterns and insight on this.
# </div>

# %% [markdown]
# 3d. Customising your Visualisations with Plotly.express
# ---
#
# To add richness to our visualisation, we can customise our visualisation using plotly.express's in-built parameters and functions. In this section, we cover the commonly used customisations that applies to most plotly visualisations:
#
# i) Axes <br>
# ii) Data colour & label <br>
# iii) Trendlines <br>
# iv) Title <br>
# v) Facet / Trellis Plots  (Aka subplots in Matplotlib) <br>
# vi) Marginal Plots<br>
# vii) Background Color
#
# In general, you can find out more about styling your visualisations in this page: https://plotly.com/python/styling-plotly-express/

# %% [markdown]
# <b>3d.i) Axes</b>
#
# Axis titles are automatically set to the column names when using Plotly Express with a data frame as input. However, if you want to customise the axes, you can use the <code>update_xaxes()</code> and <code>update_yaxes()</code> functions. In fact, you can use these functions to add a prefix to the value in the axes by passing in the <code>tickprefix</code> parameter.
#
# <br>You can read more at:  https://plotly.com/python/axes/

# %%
fig = px.scatter(creditcard_spending_df,
                 x='total_credit_card_bill',
                 y='amount_spent_on_alcohol'
)

# This is how we modify the axes title and add a prefix to the axes value
fig.update_yaxes(title_text="Credit Card Spending on Alcohol", tickprefix="$")
fig.update_xaxes(title_text="Total Credit Card Bill", tickprefix="$")

fig.show()

# %% [markdown]
# _Try moving your mouse over some of the data points to see the "$" prefix update as well!_

# %% [markdown]
# <b>3d.ii) Data Color and Labels</b>
#
# You can use the <code>color</code> parameter, and pass the name of the column whose values you want to use to assign a colour to the data. To have discrete colors, note that the data in the column should be **categorical** instead of numerical.
#
# <br>You can read more at:  https://plotly.com/python/axes/

# %%
# Add 'color' parameter to assign colours to datapoints based on customer gender
fig = px.scatter(creditcard_spending_df,
                 x='total_credit_card_bill',
                 y='amount_spent_on_alcohol',
                 color='sex'
)

fig.update_yaxes(title_text="Amount Spent on Alcohol", tickprefix="$")
fig.update_xaxes(title_text="Total Bill", tickprefix="$")

fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Isn't plotly powerful? With just one parameter change, you can instantly study the difference in behaviour between male and female clients.
# </div>

# %% [markdown]
# To change the name of the label and legend, you can use the <code>label</code> parameter and pass in a dictionary (with the key being the current default label, and value being the name you want to change it to)

# %%
# Add 'labels' parameter to customise the text of the labels
fig = px.scatter(creditcard_spending_df, 
                 x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
                 color = 'sex',
                 labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Credit Card Spending on Alcohol"}
)

fig.update_yaxes(tickprefix="$")  # Note that title_text can be excluded once you have labels
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# <b>3d.iii) Trendlines</b>
#
# You can add trendlines to show the trend of the data using the <code>trendline</code> parameter. Later in your machine learning class on regression, you will learn the significance and mechanism of ordinary least squares (ols).
#
# <br>You can read more at: https://plotly.com/python/linear-fits/

# %%
# Add 'trendline' parameter to fit a trendline using Ordinary Least Squares method
fig = px.scatter(creditcard_spending_df, 
                 x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
                 color = 'sex',
                 labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Credit Card Spending on Alcohol"},
                 trendline = 'ols'  # add trendline parameter
)

fig.update_yaxes(tickprefix="$")
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# <b>3d.iv) Title</b>
#
# To add a title to your graph, you can simply use the <code>title</code> parameter.
#
# <br>You can read more at: https://plotly.com/python/figure-labels/

# %%
# Add 'title' parameter to insert a title for the figure
fig = px.scatter(creditcard_spending_df, 
             x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
             color = 'sex',
             labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Credit Card Spending on Alcohol"},
             trendline = 'ols',
             title = 'Amount Spent on Alcohol (Male vs Females)' # add title parameter
)

fig.update_yaxes(tickprefix="$")
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# <b>3d.v) Facet / Trellis Plots</b>
#
# Facet plots, also known as trellis plots or small multiples, are figures made up of multiple subplots which have the same set of axes, where each subplot shows a subset of the data. If you have taken AI100, you will realise that this is similar to matplotlib's subplot. In Plotly, we can create multiple plots in the same figure through two parameters:
# - <code>facet_row</code> or,
# - <code>facet_col</code>

# %% [markdown]
# When you use <code>facet_row</code>:
# - the data will be sliced into different subsets based on the feature indicated for <code>facet_row</code>. Note that each unique value of the feature will be sliced into a subset on its own (e.g. smoker=No, smoker=Yes)
# - thereafter, the different subsets of data will be used in their respective graphs, and these graphs will be <b>stacked row by row</b> in the same figure
#
# <br>You can read more at: https://plotly.com/python/facet-plots/

# %%
# Add 'facet_row' parameter to create facet plot (stacked vertically)
fig = px.scatter(creditcard_spending_df, 
             x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
             color = 'sex',
             labels = {"sex": "Gender", "total_credit_card_bill": "Total Bill", "amount_spent_on_alcohol": "Spending on Alcohol"},
             trendline = 'ols',
             title = 'Amount Spent on Alcohol (Male vs Females)',
             facet_row = 'smoker' # add facet_row parameter
)

fig.update_yaxes(tickprefix="$")
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Those who have used matplotlib before, or even other visualisation libraries will realise how much easier it is to generate multiple plots in the same figure with plotly!
# </div>

# %% [markdown]
# When you use <code>facet_col</code>:
# - the data will be sliced into different subsets based on the feature indicated for <code>facet_col</code>. Note that each unique value of the feature will be sliced into a subset on its own (e.g. smoker=No, smoker=Yes)
# - thereafter, the different subsets of data will be used to their respective graphs, and these graphs will be <b>stacked side by side</b> in the same figure

# %%
# Add 'facet_col' parameter to create facet plot (stacked horizontally)
fig = px.scatter(creditcard_spending_df, 
             x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
             color = 'sex',
             labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Credit Card Spending on Alcohol"},
             trendline = 'ols',
             title = 'Amount Spent on Alcohol (Male vs Females)',
             facet_col = 'smoker' # add facet_row parameter
)

fig.update_yaxes(tickprefix="$")
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# In the event that your feature has a large number of unique values, it is possible to wrap columns using the facet_col_wrap argument. You can augment your code with the <code>facet_col_wrap</code> parameter to constrain the graphs. The number which you pass to the <code>facet_col_wrap</code> will dictate the maximum number of columns of graph in a row.

# %%
# Add 'facet_col_wrap' parameter to wrap the facet plots
fig = px.scatter(creditcard_spending_df, 
             x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
             color = 'sex',
             labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Spending on Alcohol"},
             trendline = 'ols',
             title = 'Amount Spent on Alcohol (Male vs Females)',
             facet_col = 'usual_drinking_day',
             facet_col_wrap = 2, # add facet_col_wrap parameter
)

fig.update_yaxes(tickprefix="$")
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# _For further exploration:_ More facet plot examples [here](https://plotly.com/python/facet-plots/#histogram-facet-grids).

# %% [markdown]
# <b>3d.vi) Marginal Plots</b>
#
# Certain graphs like scatter plot have unique features that allows you to add  add other kinds of plot to enrich the main graphical visualisation. In the case of scatter plot we can do so using these parameters:
# - <code>marginal_x</code> - One of 'rug', 'box', 'violin', or 'histogram'. If set, a horizontal subplot is <b>drawn above the main plot, visualizing the x-distribution</b>.
# - <code>marginal_y</code> - One of 'rug', 'box', 'violin', or 'histogram'. If set, a vertical subplot is <b>drawn to the right of the main plot, visualizing the y-distribution</b>.
#
# <br>You can read more at: https://plotly.com/python-api-reference/generated/plotly.express.scatter.html#

# %%
# Add marginal_x and marginal_y parameter to add auxiliary plots
fig = px.scatter(creditcard_spending_df, 
             x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
             color = 'sex',
             labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Credit Card Spending on Alcohol"},
             trendline = 'ols',
             title = 'Amount Spent on Alcohol (Male vs Females)',
             marginal_x = 'box',
             marginal_y = 'violin', # add marginal_x and marginal_y parameter
)

fig.update_yaxes(tickprefix="$")
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Now you can instantly compare the distrbution of the amount spent on alcohol as well as the bill amount for both male and female clients!
# </div>

# %% [markdown]
# <b>3d.vii) Background Color</b>
#
# Finally, if you want to change the background color of the plots, an easy way to do it is via the <code>template</code> parameter. You can check out the list of possible colors which you can pass in to the <code>template</code> parameter at: https://plotly.com/python/templates/

# %%
# Add template parameter to change the color scheme of the plot
fig = px.scatter(creditcard_spending_df, 
             x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
             color = 'sex',
             labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Credit Card Spending on Alcohol"},
             trendline = 'ols',
             title = 'Amount Spent on Alcohol (Male vs Females)',
             marginal_x = 'box',
             marginal_y = 'violin',
             template = 'simple_white' # added the template parameter
)

fig.update_yaxes(tickprefix="$")
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# 3e. Generate a Plotly.express Visualisation [Student Exercise]
# ---
#
# <br>
#
# <div class="alert alert-block alert-info">
#
# <b>Background:</b>
#
# - Given <code>creditcard_spending_df</code> data containing the credit card spending by a list of customers, we want to generate some visualisation to gain insights on amount spent on alcohol
#
# <b>User story:</b>
#  - Plot a scatter plot with the following features:
#     - Make use of facets to generate a facet plot <b>side-by-side</b> (one for male clients, one for female clients)
#     - Further sub-divide each facet plot into smokers and non-smokers by color
#     - Use the concept of marginal plots to set a histogram at the top of the two facet chart
#     - Set a trendline using OLS
#     - Set 'Amount Spent on Alcohol (Male vs Females)' as the title
#     - Assign a prefix '$' to the values in the y-axis and x-axis
#     - Assign the appropriate labels to "total_bill", "amount_spent_on_alcohol", "smoker", "sex" to arrive at the expected output
#
#  Expected output:
#
#  <img src='data:image/png;base64,...
# '/>

# %%
creditcard_spending_df.head()

# %%
## Write your code below
fig = px.scatter(creditcard_spending_df, 
             x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
             color = 'smoker',
             labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Credit Card Spending on Alcohol"},
             trendline = 'ols',
             title = 'Amount Spent on Alcohol (Male vs Females)',
             facet_col = 'sex',
             marginal_x = 'histogram'
)

fig.update_yaxes(tickprefix="$")
fig.update_xaxes(tickprefix="$")

fig.show()

# %% [markdown]
# 3f. Formalising how Data Transformation Phase Segues into Plotly.express Visualisations
# ---
#
# Let's formalise:
# - the workflow for working with Plotly.express Visualisations,
# - and how the dataframe you transformed/manipulated using pandas is inputted into  Plotly.express Visualisations

# %% [markdown]
# <img src='data:image/png;base64,...
# '/>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Now that you understood the big picture, we will next <b>expose you to a plethora of visualisation as well as the kind of use cases you can use these visualisations for.</div>

# %% [markdown]
# 4.Use Cases for Select Visualisations
# ===
# ***

# %% [markdown]
# 4a. Recommended Principles for Selecting Visualisations
# ---
#
# Where visualisations are concerned, the challenge is often not in the implementation but rather, how to choose the appropriate graphical visualisation to represent your data. The image below provides some criteria to help us select the right visualisation tool.

# %% [markdown]
# <img src='data:image/jpeg;base64,...
# ' width='800'/>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# However, note that these are not hard-and-fast rules. These are just tried and tested rules-of-thumbs to help you decide on the appropriate visualisation tools based on your context!</div>

# %% [markdown]
# 4b. Exposure to Select Visualisations and their Use Cases
# ---
#
# In this section, we will showcase select visualisations from each category in the Thought-Starter framework:
#
# - Relationship
# - Composition (overtime)
# - Composition (static)
# - Distribution
# - Comparison
#
# We'll also expose you to visualisations that fall into these categories, but are not featured in the above framework.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# For the rest of this section, the focus will not be on implementation and but more on the application of the visualisations. Implementation codes however will be provided, and we will point out the keypoints of the implementation codes (if any). You are highly encouraged to seek assistance from the TAs if there are areas which you do not understand after going through it on your own.
# </div>

# %% [markdown]
# 4c. Visualisations for Relationship
# ---
#
# For this category of visualisation, it involves trying to <b>establish a relationship between different features of a dataset</b>. Loosely put, we are trying to <b>compare the relationship between multiple columns in a dataset</b>.
#
# Types of charts under this category include:<br>
# i) Scatterplot <br>
# ii) Scatterplot matrices (not featured in graph icon) <br>
# iii) Heatmap (not featured in graph icon)<br>
# iv) Bubble Chart <br>
# v) Animated Bubble Chart(not featured in graph icon) <br>

# %% [markdown]
# <b>4c.i) Scatterplot</b>
#
# In the earlier <b>credit card spending dataset</b>, we used a scatterplot to establish the relationship between the credit card bill, and amount spend on alchohol. It was evident from the chart there was a positive relationship between the credit card bill and amount spent on alcohol (meaning: As the credit card bill increases, there is a strong likelihood of an increase in amount spent on alchohol). In sum, a <b>scatterplot is great when you are trying to understand the relationship between 2 features / 2 columns in a dataset at any one point in time</b>.
#
# <b>Common use cases:</b>
# - establishing relationship between Height and weight
# - establishing relationship between Floor size and house price
# - establishing relationship between Features (for smaller datasets, you can use scatterplot to help select the right features to build your machine learning model)
#
# You can read more at: https://plotly.com/python/line-and-scatter/

# %%
# Printing the data out first so you can see the name of the available features
creditcard_spending_df.head()

# %%
# Same code from previous section on customising parameters
fig = px.scatter(creditcard_spending_df, 
             x = 'total_credit_card_bill', y = 'amount_spent_on_alcohol',
             color = 'sex',
             labels = {"sex": "Gender", "total_credit_card_bill": "Total Credit Card Bill", "amount_spent_on_alcohol": "Credit Card Spending on Alcohol"},
             trendline = 'ols',
             title = 'Amount Spent on Alcohol (Male vs Females)' # add title parameter
)

fig.show()

# %% [markdown]
# <b>4c.ii) Scatterplot Matrices</b>
#
# If you want to<b> understand the relationship between all the pairs of features in a dataset in a single snapshot, you can make use of a scatterplot matrices</b>. To create a scatterplot matrices, you make use of the <code>scatter_matrix()</code> function, and you pass in a list of the names features/columns which you want to study the relationship between to the <code>dimension</code> parameter. In fact, you can also use the <code>color</code> parameter in this chart as well. Let's see an example using the same <b>credit card spending dataset</b>!<br>
#
# <b>Common use cases:</b>
# - This plot is often used by Data Scientists / Data Analysts to <b>study the relationship between features & the outcome (we are trying to predict)</b>. This helps in the selection of features for building a machine learning model. We will learn more about this from session 3 onwards.
#
# You can read more at: https://plotly.com/python/splom/

# %%
# Display data first to review useful features
creditcard_spending_df.head()

# %% [markdown]
# Notice that we pass in a list of features to the <code>dimensions</code> parameter, which are then plotted in a scatterplot against each other. Now, <b>in one snapshot, you can now study the relationship of multiple pairs of features.</b>

# %%
creditcard_spending_df.columns

# %%
fig = px.scatter_matrix(creditcard_spending_df, dimensions=["total_credit_card_bill", "amount_spent_on_alcohol", "drinking_group_size", "usual_drinking_day"],
                        labels = {"sex": "Gender", "total_credit_card_bill": "Total Bill", "amount_spent_on_alcohol": "Alcohol", "drinking_group_size": "Grp Size", "usual_drinking_day": "Day"},
                        color="smoker")
fig.show()

# %% [markdown]
# <b>4c.iii) Heatmap</b>
#
# The heatmap is another tool that helps us<b> understand the relationship between all the pairs of features in a dataset</b>.
#
# <b>Common use cases:</b>
# - This plot is often used by Data Scientists / Data Analysts to <b>study the relationship between features & the outcome (we are trying to predict)</b>. This helps in the selection of features for building a machine learning model. We will learn more about this from session 3 onwards.
#
# You can read more at: https://plotly.com/python/heatmaps/

# %% [markdown]
# Remember in our previous class in Pandas we learnt how to use the <code>corr()</code> function to calculate the relationship of all variables in a dataset? You can learn more about this function in the documentation <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html">here</a>.<br>
#
# Let's apply it to the <code>creditcard_spending_df</code>.

# %%
corr = creditcard_spending_df.corr(numeric_only=True)

# %% [markdown]
# Now, let's represent the correlation using a heatmap. All we need to do is just use the <code>imshow()</code> function, and pass in a dataframe of the values which we want to cast onto the heatmap. Here we added two parameters:
#
# - <code>color_continuous_scale</code> - which allows you to customise the color scheme of the heatmap
# - <code>text_auto</code> - which allows you to enable the display of the correlation value on each of the boxes in the heatmap (try changing it to false and see what happens)

# %%
fig = px.imshow(corr, color_continuous_scale = 'Brwnyl', text_auto = True)
fig.update_xaxes(side="top")
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Note that the heatmap's application is not just restricted to helping us studying the correlation of variables for machine learning. In fact, here is another well established use case for heatmap. <a href='https://medium.com/@marketahead.com/day-month-performance-heatmap-stock-data-analysis-8d5d981e0930'>Stock Analysis!</a>
# </div>

# %% [markdown]
# <b>4c.iv) Bubble Chart</b>
#
# While a <b>scatterplot is great when you are trying to understand the relationship between 2 features / 2 columns in a dataset at any one point in time</b>, it does not work when you are trying to measure the relationship of 3 variables at the same time. Here is where a bubble chart shines! Let's see an example using the data containing the <b>development statistics of countries</b>! In this example, we are trying to understand the relationship between <b>GDP</b>, <b>Life expectancy</b>, and <b>population size</b> for year <b>2007</b>!
#
# <b>Common use cases:</b>
# - Visualise high-dimensional data e.g. comparing multiple metrics across countries
#
# You can read more at: https://plotly.com/python/splom/

# %%
# Display data first to review useful features
countries_df = px.data.gapminder()
countries_df.head(20)

# %% [markdown]
# Before we begin, we need to make use of <b>conditional selectors in Pandas</b> to extract all the data for 2007.

# %%
# Remember your pandas data tranformation / manipulation from the previous session?
countries_2007_df = countries_df[countries_df.year==2007]
countries_2007_df

# %% [markdown]
# Implementation wise, in Plotly, <b>Bubble chart</b> is also generated through the <code>scatter()</code> function. However, we need to pass in the <code>size</code> parameter. In the example below, by passing in <code>size='pop'</code>, we are instructing plotly to vary the size of each dot in proportion to the value of the feature <b>'pop'</b> (which is basically the population). There are two other parameters in the sample code which we have not introduced before:
#
# - <code>log_x</code> When this parameter is set to <code>True</code>, you are instructing plotly to set the x-axis to a logarithmic scale (as a natural extention, to set the y-axis to a logarithmic scale you can use <code>log_y=True</code>)
# - <code>size_max</code> This parameter limits the max size of each dot based on the provided inpu

# %%
fig = px.scatter(countries_2007_df, x="gdpPercap", y="lifeExp", size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)
fig.show()

# %% [markdown]
# <b>4c.v) Animated Bubble Chart</b>
#
# We can make use of the <code>animation_frame</code> parameter to animate our bubble chart. This is particularly useful when we are trying to studying <b>the change in relationship of 3 features over time</b>.
#
# <b>Common use cases:</b>
# - Visualise high-dimensional data e.g. comparing multiple metrics across countries
# - Especially if you are trying to show highlight changes over time, this chart will be immensely useful
#
# You can read more at: https://plotly.com/python/animations/

# %%
# Display data first to review useful features
countries_df.head()

# %% [markdown]
# There are two parameters which you will use to generate the animation:
#
# - <code>animation_frame</code> This set the values for each animation frame. For example, by setting <code>animation_frame="Year"</code>, we are instructing Plotly to use vary each frame by the "year" feature in the dataframe.
# - <code>animation_group</code> This sets the values for grouping data – if available.

# %%
fig = px.scatter(countries_df, x="gdpPercap", y="lifeExp", size="pop", color="continent", 
                 hover_name="country", log_x=True, size_max=45, 
                 animation_frame="year", animation_group="country", # add animation_frame and animation_group
                 range_x=[100,100000], range_y=[25,90]              # define x & y axis range for animation duration
)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Notice that with the animated chart, it becomes very clear how immense and rapid the growth in Asia really was! And through this, you should begin to appreciate how useful this chart is when you are trying to <b>bring attention to changes in features over time</b>.
# </div>

# %% [markdown]
# We can also make use of the <code>facet_col</code> parameter we learnt earlier to further seggregate each plot based on their continent!

# %%
fig = px.scatter(countries_df, x="gdpPercap", y="lifeExp", size="pop", color="continent", 
                 hover_name="country", log_x=True, size_max=45, 
                 animation_frame="year", animation_group="country",
                 range_x=[100,100000], range_y=[25,90],
                 facet_col="continent" # add new parameter: facet_col
)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# If you think that the animated chart is just purely ornamental and has no real value, think again! <br>
# This chart was the brainchild of a world-renowned staistician. We highly recommend you watch this video to understand the wealth of information an animated chart can communicates: <br>
# YouTube video - <a href='https://www.youtube.com/watch?v=Z8t4k0Q8e8Y'>Hans Rosling: 200 years in 4 minutes - BBC News</a><br>
# TED Talk - <a href='https://www.ted.com/talks/hans_rosling_the_best_stats_you_ve_ever_seen'>Hans Rosling: The best stats you've ever seen</a>
# </div>

# %% [markdown]
# 4d. Visualisations for Composition (Overtime)
# ---
# For this category of visualisation,it involves trying to <b>illustrate the composition of your data a period of time</b>.
#
# Under this category, we will cover:<br>
# i) Stacked Column Chart <br>
# ii) Stacked Area Chart <br>

# %% [markdown]
# <b>4d.iv) Stacked Column Chart</b>
#
# Stacked Column Charts are great for part-to-whole comparisons across categories and even across time (stacked area chart is better for time though). Let's see an example using some psudeo sales data we created below for you to appreciate how to apply this visualisation technique in a business setting!
#
# <b>Common use cases:</b>
# - Sales of different categories of products on different sales channel
# - Demography of population in different countries
#
# You can read more at: https://plotly.com/python/bar-charts/

# %%
## In this cell, we create a dataframe of pseudo sales data for demonstration purposes
## Don't concern yourself too much with the code below!

import numpy as np
import pandas as pd

bank_division = pd.Series(['Retail Banking','Commercial Banking','Private Banking']*12)

series_list = [pd.Series([month]*3) for month in ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']]
month_col = pd.concat(series_list, ignore_index=True)

sales_revenue= [[np.random.randint(5,20), np.random.randint(5,8), np.random.randint(30,50)] for i in range(0,12)]
sales_revenue = sum(sales_revenue, [])

bank_revenue_df = pd.DataFrame({
    'month': month_col,
    'year': 2020,
    'bank division': bank_division,
    'sales revenue ($ Mil)': sales_revenue
})
bank_revenue_df

# %% [markdown]
# Simple use the <code>bar()</code> function, and specify the features from the dataframe which you want to use for your <code>x</code>, <code>y</code> and the <code>color</code>.

# %%
fig = px.bar(bank_revenue_df, x="month", y="sales revenue ($ Mil)", color="bank division", 
             title="Bank Revenue in 2020"
)
fig.show()

# %% [markdown]
# <b>4d.iv) Stacked Area Chart</b>
#
# Stacked Area Charts are great for part-to-whole comparisons, and also for showing how values develop over time. Let's see an example using the <code>countries_df</code> dataset which was used earlier!
#
# <b>Common use cases:</b>
# - Sales of different categories of products over time
# - Demography of population over time
# - Changes in market share over time
#
# You can read more at: https://plotly.com/python/filled-area-plots/

# %%
# Display data first to review useful features
countries_df.head()

# %% [markdown]
# For stacked area charts, you just need to use the <code>area()</code> function, and specify the features from the dataframe which you want to use for your <code>x</code>, <code>y</code> and the <code>color</code>.

# %%
fig = px.area(countries_df, x="year", y="pop", color="continent",line_group="country")
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# In the financial sector context, this visualisation tool can be used to visualise data such as changes in (1) changes over time in proportion of market share amongst banks, or (2) changes over time in proportion of domestic bank deposits.
# </div>

# %% [markdown]
# 4e. Visualisations for Composition (Static)
# ---
# For this category of visualisation,it involves trying to <b>purely illustrate the composition of your data</b>. Here, the focus is on the percentage/proportion of each category relative to each other with zero regard for what happens over time.
#
# Under this category, we will cover:<br>
# i) Pie Chart <br>
# ii) Treemap (not featured in graph icon) <br>

# %% [markdown]
# <b>4e.i) Pie Chart</b>
#
# A pie chart is best used when trying to work out the composition of something. If you have categorical data then using a pie chart would work really well as each slice can represent a different category. Let's see an example using the data containing the <b>development statistics of countries</b>! In this example, let's try to compare the population amongst all countries on the America continent in year 2007!
#
#
# <b>Common use cases:</b>
# - compare areas of growth within a business such as turnover, profit and exposure.
# - compare market shares
#
# You can read more at: https://plotly.com/python/pie-charts/

# %%
# Display data first to review useful features
import pandas as pd
 
# initialize list of lists
data = [['DBS', 148.2], ['UOB', 125.4], ['OCBC', 95.9], ['SCB', 60.3], ['HSBC', 53.6], ['Maybank', 38.5], ['CIMB', 29], ['Citibank', 17.1], ['Others', 67.5]]
 
# Create the pandas DataFrame
domestic_loans_df = pd.DataFrame(data, columns = ['Financial Institute', 'Domestic Loan by Market Share in bn (2017)'])
 
# print dataframe.
domestic_loans_df

# %% [markdown]
# For stacked area charts, you just need to use the <code>pie()</code> function, and pass the name of the column which you want to visualise in a pie chart to the <code>values</code> parameter. You can also make use of the <code>hover_data</code> and <code>labels</code> parameters to add extra elements to the label (the box pops up when you hover your cursor over the pie chart).

# %%
fig = px.pie(domestic_loans_df, values='Domestic Loan by Market Share in bn (2017)', names='Financial Institute',
             title='Singapore Domestic Loans by Market Share in 2017',
             hover_data=['Domestic Loan by Market Share in bn (2017)'])

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# <b>4e.ii) Treemap</b>
#
# A treemap is used to show the composition of a whole when there are many components. The arrangement is typically (but not always) a rectangular area divided up into smaller rectangles to represent sub-categories. The size of these sub-category rectangles represents a quantitative value.
#
# Treemaps can work well if your data falls into this scenario:
#
# - You want to visualize a part-to-whole relationship amongst a large number of categories.
# - Precise comparisons between categories is not important.
# - The data is hierarchical.
#
# Let's see an example using the data containing the <b>development statistics of countries</b>! In this example, let's try to compare the life expectancy amongst all countries in year 2007!
#
# <b>Common use cases:</b>
# - Compare effectiveness of sales channels in different countries
# - Compare market shares
# - Showcase gains and losses of stockmarket [Often used by S&P500] (https://finviz.com/map.ashx)
# - US electoral college votes
#
# You can read more at: https://plotly.com/python/treemaps/

# %%
# Display data first to review useful features
countries_df.head()

# %% [markdown]
# Before we begin, we need to use <b>conditional selectors in Pandas</b> to extract all the data for all countries in 2007.

# %%
countries_2007_df = countries_df[countries_df.year==2007]
countries_2007_df.head()

# %% [markdown]
# For treemaps, you just need to use the <code>treemap()</code> function, and pass the order of hierarchy in a list to <code>path</code>. You must indicate the column which you want to visualise to the <code>values</code> parameter. <br>
#
# Optionally, you can also modify the <code>hover_template</code> to customise the box that pops up when you hover your cursor over the treemap.

# %%
fig = px.treemap(countries_2007_df, values='pop', color='lifeExp', 
                 color_continuous_scale='RdBu',
                 path=[px.Constant('World'), 'continent', 'country']
)
fig.data[0].hovertemplate = '%{label}<br>%{value}'
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Many people tend to misuse treemap, using it in inappropriate cases just because it is sexy and they want to add some visual variety to their analysis. However, when it is used properly, it can be a very powerful tool that is superior to other visualisation techniques. Read this article for an example of a well-applied heatmap (be sure to scroll all the way to the bottom)  <a href='https://www.datarevelations.com/resources/in-praise-of-treemaps/'>In praise of Treemap!</a>
# </div>

# %% [markdown]
# 4f. Visualisations for Distribution
# ---
#
# For this category of visualisation, it is useful for trying to study the <b>distribution of certain features over time to identify outliers, trends, the normal tendency, and the range of information in your values</b>.
#
#
# Under this category, we will cover:<br>
# i) Histogram / Displot<br>
# ii) Boxplot (not featured in graph icon) <br>

# %% [markdown]
# <b>4f.i) Histogram / Displot</b>
#
# As its name suggests, Displot provides a visual representation of the underlying frequency distribution (shape) of a set of continuous data. This allows the inspection of the data for its underlying distribution (e.g., normal distribution), outliers, skewness, etc. Let's see an example using the <code>creditcard_spending_df</code> dataset which was used earlier!
#
# <b>Common use case:</b>
# - View the distribution of numerical data across different categorical values
# - Understand the quartiles of each distribution
#
# You can read more at: https://plotly.com/python/distplot/

# %%
# Display data first to review useful features
creditcard_spending_df.head()

# %% [markdown]
# Simply use the <code>histogram()</code> function, and specify the features from the dataframe which you want to use for your <code>x</code>, <code>y</code> and the <code>color</code>. Additionally, you can use the <code>marginal</code> parameter (accepts <code>box</code>, <code>violin</code> or <code>rug</code>) to add an additional distribution tool on top of the histogram.

# %%
import plotly.express as px

fig = px.histogram(creditcard_spending_df, 
                   x = 'total_credit_card_bill',
                   y = 'amount_spent_on_alcohol',
                   color = 'sex',
                   marginal = 'box' # or violin, rug
)

fig.show()

# %% [markdown]
# <b>4f.ii) Boxplot</b>
#
# A Box Plot is the visual representation of the statistical five number summary of a given data set. A Five Number Summary includes:
# - Minimum
# - First Quartile
# - Median (Second Quartile)
# - Third Quartile
# - Maximum
#
# <b>Common use case:</b>
# - Compare performance across machine learning models on test dataset
# - Showcase survey responses
#
# You can read more at: https://plotly.com/python/box-plots/

# %%
# Display data first to review useful features
creditcard_spending_df.head()

# %% [markdown]
# Simply use the <code>box()</code> function, and specify the features from the dataframe which you want to use for your <code>x</code>, <code>y</code> and (optionally) <code>color</code>.

# %%
fig = px.box(creditcard_spending_df, x="usual_drinking_time", y="total_credit_card_bill")  # optional: you may include color="sex"  - see what a difference it makes!
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Boxplot is a very well-used visualisation technique. This is especially so when it comes to comparing the performance of machine learning models, like the image below:
#
# <img src='data:image/png;base64,...
# ' width='400'/>
#
# In the subsequent session, we will illustrate how to visualise the performance of your machine learning models.
# </div>

# %% [markdown]
# 4g. Visualisations for Comparison
# ---
#
# This category of visualisation is concerned with drawing comparison between two or more items on different parameters. You can either compare two items or you can use various parameters or comparison points to weigh up to two or more items.
#
# Under this category, we will cover:<br>
# i) Line Chart <br>

# %% [markdown]
# <b>4g.i) Line Chart</b>
#
# Line charts are used to track changes over short and long periods of time. When smaller changes exist, line charts are better to use than bar graphs. Line charts can also be used to compare changes over the same period of time for more than one group.
#
# Let's see an example using the <code>stock_df</code> dataset which was used earlier!
#
# <b>Common use cases:</b>
# - Comparing performance of machine learning model
# - Showcase survey responses
#
# You can read more at: https://plotly.com/python/line-charts/

# %%
# Run this cell to install yfinance (you only need to do this once)
# !pip install yfinance==0.2.28

# %%
# In this cell, we use yfinance library to extract stock prices

import pandas as pd
import datetime
import yfinance as yf
from pandas import Series, DataFrame

start_date = '2013-01-01'
end_date = '2020-01-31'

stocks_OHLCV_df = yf.download(['AAPL', 'GE', 'MSFT'], start = start_date, end = end_date)
stocks_df = stocks_OHLCV_df['Adj Close'].reset_index()
stocks_df

# %% [markdown]
# Simply use the <code>line()</code> function, and specify the features from the dataframe which you want to use for your x-axis(<code>x</code> parameter) and y-axis (<code>y</code> parameter). As you can see, a line chart is really powerful when you are trying to depict trends over a period of time.

# %%
fig = px.line(stocks_df, x="Date", y="AAPL")

fig.show()

# %% [markdown]
# You can also have multiple lines on the same figure. All you have to do is pass a list of the column names to the <code>y</code> parameter instead of a single column name

# %%
fig = px.line(stocks_df, x="Date", y=["AAPL","GE","MSFT"], labels={"variable": "Stock Symbols"})

fig.show()

# %% [markdown]
# 4h. Visualisations for Comparison - Bar Chart [Student Exercise]
# ---
#
# <br>
#
# <div class="alert alert-block alert-info">
#
# <b>Background:</b>
#
# - Given a dataset on the ranking of the top banks in US, we want to gain insights on the top 10 banks in US.
#
# <b>User story:</b>
#  - Plot a bar chart with the following features:
#     - Using a <b>bar chart</b> (another excellent visualisation technique for comparison), compare the market capitalisation of the top 10 US banks
#     - Use colors to distinguish the state in which the banks are headquartered in
#     - Set 'Market Capitalization of Top 10 US Banks' as the title
#     - Bonus: To reorder the bar charts, we'll need some extra help from the [Plotly documentation](https://plotly.com/python/categorical-axes/), under the section "Controlling the Categorical Order with Plotly Express". (Hint: you need to fill in the `category_orders` parameter with a dictionary)
#
#
# Expected output:
#
#  <img src='data:image/png;base64,...
# '/>

# %%
# Run this cell below before you work on the student exercise
top_banks_df = pd.read_csv("data/top_100_banks_in_US.csv")
top_banks_df.head(10)

# %%
## Write your code below

# First, save the top 10 banks to a new df
top_10_banks_df = top_banks_df.head(10)

# Plot bar chart here
fig = px.bar(top_10_banks_df, 
             x='Bank name', y='Market capitalization (Billions of USD)', 
             color='Headquarters location',
             category_orders={"Bank name": top_10_banks_df['Bank name']},
             title='Market Capitalization of Top 10 US Banks'
)

# Alternatively, you can do this instead of category_orders
# fig.update_xaxes(categoryorder='total descending')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Food for Thought: Say you'd like to visualise the proportion of top 50 universities across countries. <br>
#     Which visualisation chart would you recommend in this case, and why?
# </div>

# %% [markdown]
# 5.Useful Resources / Advice
# ===
# ***

# %% [markdown]
# 5a. Plotly Datasets
# ---
#
# Throughout this session, you would have seen multiple usage of something like <code>px.data.gapminder()</code>, and you may be wondering what this code does. Plotly express has an in-built library of several datasets which you can easily just pull using the <code>data</code> attribute. The intent of this dataset library is to provide users with a quick and easy way of trying out the visualisations before customising / contextualising them for their own datasets.<br>
#
# You can see the list of available datasets here:https://plotly.com/python-api-reference/generated/plotly.data.html#module-plotly.data

# %% [markdown]
# 5b. Deploying your Visualisation with Dash
# ---
#
# One of the selling points of plotly is that you can <b>easily integrate it with Dash to deploy your visualisations</b>. The upside of deploying (or uploading) your work to the cloud is that it can be easily shared with others via just a web URL. The following sample code provides you an idea of how easy it is to deploy your work with Plotly + Dash to a local link that can be accessible by you via URL.

# %% [markdown]
# Say for example we just completed a visualisation which our boss (who has no technical knowledge) tasked us to worked on. In this case, we can hardly send our jupyter notebook as he most likely would not even know how to initiate the notebook. Here is where Dash comes in handy! To start, <b>first we have to generate a visualisation</b> below with plotly.

# %%
line_chart_plot = px.line(stocks_df, x="Date", y=["AAPL","GE","MSFT"], labels={"variable": "Stock Symbols"})

line_chart_plot.show()

# %%
# Run this cell to install Dash (you only need to do this once)
# !pip install dash==2.14.0

# %% [markdown]
# Next, all we need to do is just pass in the visualisation we generated to the <code>figure</code> parameter and run the cell! If you scroll to the bottom of the main webpage on plotly.express, you will find the below sample code as well:
# https://plotly.com/python/plotly-express/

# %%
import dash
from dash import dcc
from dash import html

app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=line_chart_plot)           # Simply assign your line_chart_plot visualisation to 'figure' parameter
])

app.run_server(debug=True, use_reloader=False)  # Turn off reloader if inside Jupyter

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Once you run the above cell, you can click this URL to access your visualisation:<br/>
# <a href="http://localhost:8050/">http://localhost:8050/</a>
#
#
# Note that in this case, you <b>can only access that URL from your computer because this visualisation is hosted on your local computer</b> (<code>127.0.0.1</code> is an alias for <code>localhost</code>.), and most of your machines have firewalls in place.  That said, we hope you have gained some additional exposure to the world of deployment and are more aware of the toolsets at your disposal.<br>
#
# If you'd like to learn more about deploying to a URL that can be accessible by the public (with Github & Heroku), you are free to check out this [tutorial](https://austinlasseter.medium.com/how-to-deploy-a-simple-plotly-dash-app-to-heroku-622a2216eb73).
#
# <br>
#
# Thankfully, in most Data Science Teams, the Data Scientists / Data Analyst will not be the one in charge of deploying your visualisations / predictive models. However, if you are interested in this, watch out for our free supplementary classes on deployment.
# </div>

# %% [markdown]
# 5c. Common Fallacies in Data Visualisations
# ---
#
# While data visualisation is a very powerful technique, if used wrongly it can mislead people instead of informing them:
#
# <img src='data:image/png;base64,...
# '/>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# What is wrong with the above chart?
# </div>

# %% [markdown]
# This link provides a very good introduction to the common fallacies committed in visualisation: https://venngage.com/blog/misleading-graphs/. After you read this, be mindful not to commit these fallacies, so as not to mislead your audience!
